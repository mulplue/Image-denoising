# %%
import argparse
import numpy as np
import pandas as pd

from utils.evaluate import *
from utils.img import get_imgs

# %%
_, restore_imgs = get_imgs("./dataset/test/restore_hejunF1/")
_, restore_imgs = get_imgs("./dataset/test/restore_jiahe/")

# %%
restore_imgs
# Out:
# [array([[[176, 160, 171],
#          [200, 185, 196],
#          [205, 199, 201],
#          ...,
#          [192, 198, 190],
#          [194, 192, 188],
#          [196, 195, 194]],
#
#         [[202, 195, 191],
#          [201, 201, 199],
#          [205, 199, 203],
#          ...,
#          [197, 194, 191],
#          [195, 194, 190],
#          [194, 193, 186]],
#
#         [[206, 204, 204],
#          [203, 200, 197],
#          [201, 199, 196],
#          ...,
#          [196, 193, 190],
#          [192, 190, 186],
#          [195, 191, 187]],
#
#         ...,
#
#         [[232, 235, 229],
#          [234, 240, 234],
#          [242, 238, 241],
#          ...,
#          [236, 236, 232],
#          [236, 234, 236],
#          [236, 234, 234]],
#
#         [[245, 224, 222],
#          [244, 243, 237],
#          [242, 240, 238],
#          ...,
#          [238, 235, 231],
#          [237, 229, 233],
#          [237, 233, 230]],
#
#         [[161, 255, 255],
# ...
