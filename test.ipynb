# %%
import argparse
import numpy as np
import pandas as pd

from utils.evaluate import *
from utils.img import get_imgs

# %%
_, restore_imgs = get_imgs("./dataset/test/restore_yuqing/")
_, restore_imgs = get_imgs("./dataset/test/restore_yuqing/")

# %%
restore_imgs
# Out:
# [array([[[202, 200, 204],
#          [202, 203, 202],
#          [202, 203, 201],
#          ...,
#          [196, 195, 191],
#          [199, 195, 189],
#          [200, 196, 189]],
#
#         [[200, 200, 201],
#          [201, 203, 201],
#          [202, 204, 199],
#          ...,
#          [196, 195, 189],
#          [197, 193, 189],
#          [196, 192, 190]],
#
#         [[208, 208, 206],
#          [203, 203, 201],
#          [199, 199, 199],
#          ...,
#          [197, 196, 189],
#          [196, 191, 189],
#          [192, 188, 189]],
#
#         ...,
#
#         [[242, 240, 244],
#          [235, 240, 244],
#          [243, 237, 244],
#          ...,
#          [238, 235, 240],
#          [238, 234, 241],
#          [235, 233, 241]],
#
#         [[246, 240, 244],
#          [243, 240, 244],
#          [244, 239, 244],
#          ...,
#          [238, 235, 241],
#          [237, 235, 241],
#          [238, 234, 241]],
#
#         [[243, 242, 246],
# ...
